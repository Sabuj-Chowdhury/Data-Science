# %%
import pandas as pd

# %% [markdown]
# #**Read a .csv from a URL with Pandas**

# %% [markdown]
# target website : [https://www.football-data.co.uk/data.php](https://www.football-data.co.uk/data.php)

# %%
# reading 1 csv file from the website
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2425/E0.csv')

# %%
# showing dataframe
df_premier21
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  16/08/2024  20:00     Man United       Fulham     1     0   H     0
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool     0     2   A     0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves     2     0   H     1
# 3    E0  17/08/2024  15:00        Everton     Brighton     0     3   A     0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton     1     0   H     1
# ..   ..         ...    ...            ...          ...   ...   ...  ..   ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton     0     1   A     0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea     0     1   A     0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal     1     2   A     0
# 378  E0  25/05/2025  16:00      Tottenham     Brighton     1     4   A     1
# 379  E0  25/05/2025  16:00         Wolves    Brentford     1     1   D     0
#
# ...

# %%
# rename columns
df_premier21.rename(columns={'FTHG':'Home_Goals',
                             'FTAG':'Away_Goals'},inplace=True)

# %%
#show the dataframe
df_premier21
# Out:
#     Div        Date   Time       HomeTeam     AwayTeam  Home_Goals  \
# 0    E0  16/08/2024  20:00     Man United       Fulham           1
# 1    E0  17/08/2024  12:30        Ipswich    Liverpool           0
# 2    E0  17/08/2024  15:00        Arsenal       Wolves           2
# 3    E0  17/08/2024  15:00        Everton     Brighton           0
# 4    E0  17/08/2024  15:00      Newcastle  Southampton           1
# ..   ..         ...    ...            ...          ...         ...
# 375  E0  25/05/2025  16:00      Newcastle      Everton           0
# 376  E0  25/05/2025  16:00  Nott'm Forest      Chelsea           0
# 377  E0  25/05/2025  16:00    Southampton      Arsenal           1
# 378  E0  25/05/2025  16:00      Tottenham     Brighton           1
# 379  E0  25/05/2025  16:00         Wolves    Brentford           1
#
#      Away_Goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0             0   H     0     0  ...     1.86     2.07   1.83   2.11     1.88
# ...

# %% [markdown]
# #**Read .csv from Multiple URLs with Pandas**

# %% [markdown]
# https://www.football-data.co.uk/mmz4281/2122/E0.csv

# %% [markdown]
# **Link : Root + season + league**

# %%
#link structure
"https://www.football-data.co.uk/mmz4281/" + "2122" + "/" + "E0" + ".csv"
# Out:
# 'https://www.football-data.co.uk/mmz4281/2122/E0.csv'

# %%
# create a root variable
root = "https://www.football-data.co.uk/mmz4281/"

# %% [markdown]
# #Multiple leagues
#
#
#
# *   https://www.football-data.co.uk/mmz4281/2122/E0.csv
#
# *   https://www.football-data.co.uk/mmz4281/2122/E1.csv
#
# *   https://www.football-data.co.uk/mmz4281/2122/E2.csv
# *   https://www.football-data.co.uk/mmz4281/2122/E3.csv
#
# *   https://www.football-data.co.uk/mmz4281/2122/EC.csv

# %%
from __future__ import unicode_literals
#creating list of the leagues
leagues =['E0','E1','E2','E3','EC']
# to store all the datafrane
frames = []
#loop through leagues, read multiple csv and append it into the list
for league in leagues:
  df = pd.read_csv(root + '2122' + '/' +league + '.csv',encoding='unicode_escape')
  frames.append(df)

# %%
#length of the frames
len(frames)
# Out:
# 5

# %%
# show 1st, 2nd and 3rd element
frames[2].head(3)
# Out:
#   Div        Date   Time   HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E2  07/08/2021  15:00     Bolton  Milton Keynes Dons     3     3   D     1
# 1  E2  07/08/2021  15:00  Cambridge              Oxford     1     1   D     0
# 2  E2  07/08/2021  15:00      Crewe          Cheltenham     1     1   D     1
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     1  ...     1.97 -0.25      1.90      1.95   1.91   1.97     1.99
# 1     1  ...     1.86  0.25      2.08      1.73   2.12   1.78     2.12
# 2     1  ...     1.69 -0.25      2.00      1.85   1.99   1.90     2.04
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.01     1.90     1.92
# 1     1.82     2.06     1.77
# 2     1.95     1.96     1.87
#
# [3 rows x 106 columns]

# %% [markdown]
# #Multiple Seasons

# %%
for season in range(10,25):
  print(str(season) + str(season+1))
# Out:
# 1011
# 1112
# 1213
# 1314
# 1415
# 1516
# 1617
# 1718
# 1819
# 1920
# 2021
# 2122
# 2223
# 2324
# 2425

# %%
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []
# loop through range of seasons and insert new column
for league in leagues:
  for season in range(10,25):
    df=pd.read_csv(root + str(season) + str(season+1) + '/' + league + '.csv', encoding='unicode_escape')
    df.insert(1,'Season',season)
    frames.append(df)

# %%
# total frames (15 seasons x 5 leagues)
len(frames)
# Out:
# 75

# %%
frames[48]
# Out:
#     Div  Season      Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E3      13  03/08/13            Bury  Chesterfield     0     2   A     0
# 1    E3      13  03/08/13      Cheltenham        Burton     2     2   D     2
# 2    E3      13  03/08/13          Exeter   Bristol Rvs     2     1   H     0
# 3    E3      13  03/08/13  Fleetwood Town   Dag and Red     3     1   H     2
# 4    E3      13  03/08/13  Newport County    Accrington     4     1   H     2
# ..   ..     ...       ...             ...           ...   ...   ...  ..   ...
# 547  E3      13  03/05/14     Northampton        Oxford     3     1   H     2
# 548  E3      13  03/05/14      Portsmouth      Plymouth     3     3   D     2
# 549  E3      13  03/05/14      Scunthorpe          York     2     2   D     2
# 550  E3      13  03/05/14        Southend        Burton     1     0   H     1
# 551  E3      13  03/05/14         Torquay       Wycombe     0     3   A     0
#
# ...

# %% [markdown]
# #Organize All The Data in a Dictionary

# %%
# create a dictionary with original name of league as key
dict_countries = {
              'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2',
              'German Bundesliga':'D1',
              'English Premier League':'E0', 'English League 1':'E2', 'English League 2':'E3',
             }

# %%
for league in dict_countries:
  print("Keys: ", league, ", values: ", dict_countries[league])
# Out:
# Keys:  Spanish La Liga , values:  SP1
# Keys:  Spanish Segunda Division , values:  SP2
# Keys:  German Bundesliga , values:  D1
# Keys:  English Premier League , values:  E0
# Keys:  English League 1 , values:  E2
# Keys:  English League 2 , values:  E3

# %%
dict_historical_data = {}

# looping through key elements
for league in dict_countries:
    frames = [] # one dataframe per league
    for season in range(15, 21):
        df = pd.read_csv(root + str(season) + str(season+1) + "/" + dict_countries[league]+ ".csv")
        df.insert(1, 'season', season)
        frames.append(df)
    df_frames = pd.concat(frames) # storing all seasons of a league in a single dataframe
    dict_historical_data[league] = df_frames # assigning dataframe to a new dictionary

# %%
# show dataframe inside dict_historical_data
dict_historical_data['Spanish La Liga']
# Out:
#      Div  season        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    SP1      15    21/08/15       Malaga     Sevilla     0     0   D     0
# 1    SP1      15    22/08/15   Ath Madrid  Las Palmas     1     0   H     1
# 2    SP1      15    22/08/15      Espanol      Getafe     1     0   H     1
# 3    SP1      15    22/08/15    La Coruna    Sociedad     0     0   D     0
# 4    SP1      15    22/08/15    Vallecano    Valencia     0     0   D     0
# ..   ...     ...         ...          ...         ...   ...   ...  ..   ...
# 375  SP1      20  22/05/2021      Osasuna    Sociedad     0     1   A     0
# 376  SP1      20  22/05/2021  Real Madrid  Villarreal     2     1   H     0
# 377  SP1      20  22/05/2021   Valladolid  Ath Madrid     1     2   A     1
# 378  SP1      20  23/05/2021      Granada      Getafe     0     0   D     0
# 379  SP1      20  23/05/2021      Sevilla      Alaves     1     0   H     0
#
# ...
