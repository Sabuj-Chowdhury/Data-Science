# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# #**Adding a new column**

# %% [markdown]
# ###Adding a new column with a scalar value

# %%
# adding new column to dataframe
df_exams['language score']= 80
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                80
# 1                80
# 2                80
# 3                80
# 4                80
# ..              ...
# 995              80
# 996              80
# 997              80
# 998              80
# 999              80
#
# [1000 rows x 9 columns]

# %% [markdown]
# #Adding a new column with an array

# %% [markdown]
# The dataframe has 1000 rows, so we need to create an array with 1000 elements

# %%
# import numpy
import numpy as np

# %%
# create an array of 1000 elements
language_score=np.arange(0,1000)

# %%
# length of the array
len(language_score)
# Out:
# 1000

# %%
# adding a new column to dataframe with an array
df_exams['language score']= language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
# create random integer numbers between 1 and 100
int_language_score=np.random.randint(1,100, size = 1000)

# %%
# min value inclusive and high value exclusive
print(min(int_language_score))
print(max(int_language_score))
# Out:
# 1
# 99

# %%
# adding a new column to dataframe with an array
df_exams['language score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                35
# 1                94
# 2                11
# 3                99
# 4                30
# ..              ...
# 995              57
# 996              58
# 997              17
# 998               8
# 999              48
#
# [1000 rows x 9 columns]

# %%
# create random float numbers between 1 and 100 and for size 100
np.random.uniform(1,100, size = 100)
# Out:
# array([83.47390117, 69.41974995, 38.94765336,  7.5283331 , 18.27126396,
#        37.6097574 , 86.38442624, 21.61722407, 15.82846062, 73.81984242,
#        75.43366271, 31.0262504 , 97.84422834, 88.84977402, 19.40445883,
#        63.90551873,  5.5715688 , 30.15337691, 72.4070963 , 82.64497194,
#        12.5928262 , 92.22184991, 14.14978789, 71.06547456, 64.13445033,
#        15.70147196, 52.73377436, 78.70959718, 90.46145167, 81.7750266 ,
#        36.06370219, 97.6096779 , 38.0593019 , 15.84428682,  3.96156378,
#        55.59155594, 35.60652291, 42.31320098, 60.06721387, 48.32058153,
#        14.8856506 , 34.15188392, 35.52881672, 52.27104373,  5.88276235,
#        56.85009448, 47.90269243, 15.90087379, 74.10676599,  8.63028546,
#         9.42221268, 75.45112879, 52.60215097, 30.70598793, 36.41676001,
#        38.57692454, 98.2874226 , 84.05892379, 64.95577254, 47.71232123,
#        93.87348712, 87.35147384,  7.91343561, 41.36305763, 29.93128025,
#        36.81306215, 13.25829968, 90.61355812, 91.74486457,  7.05898041,
#        18.56510908, 34.96240033, 50.36244475, 97.80506466, 58.99700498,
#         3.32159331, 89.01731921, 51.68256288, 33.99154175, 11.82277722,
#        40.50463391, 68.74376244, 42.6763577 , 65.24516902, 59.1901359 ,
#        36.87564442, 94.50849151, 91.35883112, 75.98045057, 29.08223921,
#        89.79706267, 45.36601121, 10.32773566, 41.04902118, 24.06946221,
#        23.71177855, 97.89541106, 73.52704284, 32.47068468, 63.10049527])
