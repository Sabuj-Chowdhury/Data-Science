# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #1 Creating a dataframe from an Array
#
# ### 1.1  Option 1

# %%
# creating an array using numpy
data = np.array([[1,4],[2,5],[3,6]])

# %%
# creating a datafrane
df = pd.DataFrame(data, index=['row1','row2','row3'],
             columns=['col1','col2'])

# %%
# show the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ### 1.2 Option 2

# %%
# creating an array with list shape
data = [[1,4],[2,5],[3,6]]

# %%
# creating a datafrane
df = pd.DataFrame(data,index=['row1','row2','ro3'],columns=['col1','col2'])

# %%
# show the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# ro3      3     6

# %% [markdown]
# #2 Creating a Dataframe from a Dictionary

# %%
#list used for this example
states = ['California','Texas','Florida','New York']
population = [39613493,29730311,21944577,19299981]

# %%
#storing list within a dictionary
dict_states = {'States':states,'Population':population}

# %%
#creating the dataframe
df_population = pd.DataFrame(dict_states, index=['row0','row1','row2','row3'])

# %%
#showing the dataframe
df_population
# Out:
#           States  Population
# row0  California    39613493
# row1       Texas    29730311
# row2     Florida    21944577
# row3    New York    19299981

# %% [markdown]
# # 3 Creating a DataFrame from a csv file

# %%
#reading the csv file
df_exam=pd.read_csv('StudentsPerformance.csv')

# %%
# shows first 5 rows in a dataframe

# %%
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
